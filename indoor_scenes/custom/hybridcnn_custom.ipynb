# %% [markdown]
# #We build a custom multi-branch CNN with naive Inception module from scratch and train it on the Indoor Scenes CVPR 2019 dataset.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
itsahmad_indoor_scenes_cvpr_2019_path = kagglehub.dataset_download('itsahmad/indoor-scenes-cvpr-2019')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/itsahmad/indoor-scenes-cvpr-2019?dataset_version_number=1...
# 100%|██████████| 2.34G/2.34G [01:48<00:00, 23.1MB/s]
# Extracting files...
# Data source import complete.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1: Load image paths and labels from TrainImages.txt and TestImages.txt

# %%
import os
from sklearn.model_selection import train_test_split

rootDir = os.path.join(itsahmad_indoor_scenes_cvpr_2019_path, 'indoorCVPR_09/Images')

# List all image paths and their class labels
allData = []
for label in sorted(os.listdir(rootDir)):
    classDir = os.path.join(rootDir, label)
    if os.path.isdir(classDir):
        for file in os.listdir(classDir):
            if file.endswith(('.jpg', '.jpeg', '.png')):
                imgPath = os.path.join(classDir, file)
                allData.append((imgPath, label))

# Stratified split: 80% train, 10% val, 10% test
trainData, tempData = train_test_split(
    allData, test_size=0.2, stratify=[label for _, label in allData], random_state=42
)
valData, testData = train_test_split(
    tempData, test_size=0.5, stratify=[label for _, label in tempData], random_state=42
)

# Label mapping
labelNames = sorted(set([label for _, label in allData]))
labelToIndex = {label: idx for idx, label in enumerate(labelNames)}
classNames = labelNames

print(f"Loaded: Train = {len(trainData)}, Val = {len(valData)}, Test = {len(testData)}")
# Out:
# Loaded: Train = 12491, Val = 1561, Test = 1562

# %% [markdown]
# ## 2: Create custom PyTorch Dataset using parsed image-label pairs

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

trainTransform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2),
    transforms.RandomAffine(degrees=15, shear=10),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])




class SceneDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        imgPath, label = self.data[idx]
        image = Image.open(imgPath).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, labelToIndex[label]

# %% [markdown]
# ## 3: Create DataLoaders for training, validation, and testing

# %%
batchSize = 32

trainDataset = SceneDataset(trainData, trainTransform)
valDataset = SceneDataset(valData, transform)
testDataset = SceneDataset(testData, transform)

trainLoader = DataLoader(trainDataset, batch_size=batchSize, shuffle=True)
valLoader = DataLoader(valDataset, batch_size=batchSize, shuffle=False)
testLoader = DataLoader(testDataset, batch_size=batchSize, shuffle=False)

classNames = labelNames

# %%
def showSamples(dataLoader, classNames, title="Sample Images"):
    images, labels = next(iter(dataLoader))
    plt.figure(figsize=(12, 4))
    for i in range(5):
        img = images[i].permute(1, 2, 0).numpy()  # Convert CHW → HWC
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # Unnormalize
        img = np.clip(img, 0, 1)
        plt.subplot(1, 5, i+1)
        plt.imshow(img)
        plt.title(classNames[labels[i].item()])
        plt.axis('off')
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

showSamples(trainLoader, classNames, title="Train Samples")
showSamples(valLoader, classNames, title="Validation Samples")

# %% [markdown]
# ## 4: Define the custom multi-branch CNN using bottleneck Inception block

# %%
import torch
import torch.nn as nn

class HybridEfficientCNN_MIT67(nn.Module):
    def __init__(self, num_classes=67):
        super(HybridEfficientCNN_MIT67, self).__init__()

        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 64, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),  # 224 -> 112

            # Block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),  # 112 -> 56

            # Block 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),  # 56 -> 28

            # SE Attention block
            SEBlock(256),

            # Block 4
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d((1, 1))  # 1x1x512
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        return self.classifier(x)

# SE Block reused
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(channels // reduction, channels),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.shape
        se = self.pool(x).view(b, c)
        se = self.fc(se).view(b, c, 1, 1)
        return x * se

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = HybridEfficientCNN_MIT67(num_classes=67).to(device)
summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# HybridEfficientCNN_MIT67                 [1, 67]                   --
# ├─Sequential: 1-1                        [1, 512, 1, 1]            --
# │    └─Conv2d: 2-1                       [1, 64, 224, 224]         4,864
# │    └─BatchNorm2d: 2-2                  [1, 64, 224, 224]         128
# │    └─ReLU: 2-3                         [1, 64, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 64, 112, 112]         --
# │    └─Conv2d: 2-5                       [1, 128, 112, 112]        73,856
# │    └─ReLU: 2-6                         [1, 128, 112, 112]        --
# │    └─Conv2d: 2-7                       [1, 128, 112, 112]        147,584
# │    └─BatchNorm2d: 2-8                  [1, 128, 112, 112]        256
# │    └─ReLU: 2-9                         [1, 128, 112, 112]        --
# │    └─MaxPool2d: 2-10                   [1, 128, 56, 56]          --
# │    └─Conv2d: 2-11                      [1, 256, 56, 56]          295,168
# │    └─ReLU: 2-12                        [1, 256, 56, 56]          --
# │    └─Conv2d: 2-13                      [1, 256, 56, 56]          590,080
# │    └─BatchNorm2d: 2-14                 [1, 256, 56, 56]          512
# │    └─ReLU: 2-15                        [1, 256, 56, 56]          --
# │    └─MaxPool2d: 2-16                   [1, 256, 28, 28]          --
# │    └─SEBlock: 2-17                     [1, 256, 28, 28]          --
# │    │    └─AdaptiveAvgPool2d: 3-1       [1, 256, 1, 1]            --
# │    │    └─Sequential: 3-2              [1, 256]                  8,464
# │    └─Conv2d: 2-18                      [1, 512, 28, 28]          1,180,160
# │    └─BatchNorm2d: 2-19                 [1, 512, 28, 28]          1,024
# │    └─ReLU: 2-20                        [1, 512, 28, 28]          --
# │    └─AdaptiveAvgPool2d: 2-21           [1, 512, 1, 1]            --
# ├─Sequential: 1-2                        [1, 67]                   --
# │    └─Flatten: 2-22                     [1, 512]                  --
# │    └─Dropout: 2-23                     [1, 512]                  --
# │    └─Linear: 2-24                      [1, 256]                  131,328
# │    └─ReLU: 2-25                        [1, 256]                  --
# │    └─Linear: 2-26                      [1, 67]                   17,219
# ==========================================================================================
# Total params: 2,450,643
# Trainable params: 2,450,643
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 6.72
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 115.61
# Params size (MB): 9.80
# Estimated Total Size (MB): 126.02
# ==========================================================================================

# %% [markdown]
# 5: Setup device, loss function, optimizer, LR scheduler, and early stopping

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HybridEfficientCNN_MIT67(num_classes=67).to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-4, weight_decay=5e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)
earlyStopPatience = 7
batchSize = 64

# %%
import time

def trainModel(model, trainLoader, valLoader, criterion, optimizer, scheduler, epochs=50, earlyStopPatience=5):
    bestValAcc = 0
    patienceCounter = 0

    trainAccList, valAccList, trainLossList, valLossList = [], [], [], []

    for epoch in range(epochs):
        start_time = time.time()

        model.train()
        totalTrainLoss, correctTrain, totalTrain = 0, 0, 0

        for images, labels in trainLoader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            totalTrainLoss += loss.item()
            _, preds = outputs.max(1)
            correctTrain += (preds == labels).sum().item()
            totalTrain += labels.size(0)

        trainAcc = correctTrain / totalTrain
        trainLoss = totalTrainLoss / len(trainLoader)

        valLoss, valAcc = evaluateModel(model, valLoader, criterion)

        trainAccList.append(trainAcc)
        valAccList.append(valAcc)
        trainLossList.append(trainLoss)
        valLossList.append(valLoss)

        scheduler.step()

        elapsed_time = time.time() - start_time
        print(f"Current LR: {scheduler.get_last_lr()[0]:.6f}")
        print(f"Epoch {epoch+1:02d} | Train Acc: {trainAcc:.4f} | Val Acc: {valAcc:.4f} | "
              f"Train Loss: {trainLoss:.4f} | Val Loss: {valLoss:.4f} | Time: {elapsed_time:.2f}s")

        if valAcc > bestValAcc:
            bestValAcc = valAcc
            patienceCounter = 0
            torch.save(model.state_dict(), "bestModel.pth")
        else:
            patienceCounter += 1
            if patienceCounter >= earlyStopPatience:
                print("Early stopping triggered.")
                break

    return trainAccList, valAccList, trainLossList, valLossList

# %%
def evaluateModel(model, dataLoader, criterion):
    model.eval()
    totalLoss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for images, labels in dataLoader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            totalLoss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    avgLoss = totalLoss / len(dataLoader)
    accuracy = correct / total
    return avgLoss, accuracy

# %%
trainAccList, valAccList, trainLossList, valLossList = trainModel(
    model, trainLoader, valLoader, criterion, optimizer, scheduler,
    epochs=50, earlyStopPatience=5
)
# Out:
# Current LR: 0.000200
# Epoch 01 | Train Acc: 0.0878 | Val Acc: 0.1217 | Train Loss: 3.8564 | Val Loss: 3.6965 | Time: 223.66s
# Current LR: 0.000200
# Epoch 02 | Train Acc: 0.1086 | Val Acc: 0.1121 | Train Loss: 3.7080 | Val Loss: 3.7108 | Time: 220.23s
# Current LR: 0.000200
# Epoch 03 | Train Acc: 0.1311 | Val Acc: 0.1634 | Train Loss: 3.6189 | Val Loss: 3.5041 | Time: 219.17s
# Current LR: 0.000199
# Epoch 04 | Train Acc: 0.1517 | Val Acc: 0.1832 | Train Loss: 3.5315 | Val Loss: 3.3761 | Time: 219.38s
# Current LR: 0.000199
# Epoch 05 | Train Acc: 0.1704 | Val Acc: 0.2037 | Train Loss: 3.4520 | Val Loss: 3.3330 | Time: 219.10s
# Current LR: 0.000198
# Epoch 06 | Train Acc: 0.1872 | Val Acc: 0.1678 | Train Loss: 3.3784 | Val Loss: 3.4274 | Time: 220.61s
# Current LR: 0.000198
# Epoch 07 | Train Acc: 0.2045 | Val Acc: 0.1890 | Train Loss: 3.3212 | Val Loss: 3.3966 | Time: 218.40s
# Current LR: 0.000197
# Epoch 08 | Train Acc: 0.2181 | Val Acc: 0.2575 | Train Loss: 3.2650 | Val Loss: 3.1624 | Time: 218.80s
# Current LR: 0.000196
# Epoch 09 | Train Acc: 0.2322 | Val Acc: 0.2767 | Train Loss: 3.2159 | Val Loss: 3.0564 | Time: 219.74s
# Current LR: 0.000195
# Epoch 10 | Train Acc: 0.2507 | Val Acc: 0.3024 | Train Loss: 3.1685 | Val Loss: 2.9919 | Time: 221.23s
# Current LR: 0.000194
# Epoch 11 | Train Acc: 0.2587 | Val Acc: 0.2793 | Train Loss: 3.1280 | Val Loss: 2.9990 | Time: 221.84s
# Current LR: 0.000193
# Epoch 12 | Train Acc: 0.2684 | Val Acc: 0.3133 | Train Loss: 3.0950 | Val Loss: 2.9175 | Time: 222.04s
# Current LR: 0.000192
# Epoch 13 | Train Acc: 0.2735 | Val Acc: 0.3331 | Train Loss: 3.0564 | Val Loss: 2.8764 | Time: 221.45s
# Current LR: 0.000190
# Epoch 14 | Train Acc: 0.2839 | Val Acc: 0.3242 | Train Loss: 3.0247 | Val Loss: 2.9111 | Time: 221.16s
# Current LR: 0.000189
# Epoch 15 | Train Acc: 0.2911 | Val Acc: 0.3607 | Train Loss: 2.9886 | Val Loss: 2.8002 | Time: 221.59s
# Current LR: 0.000188
# Epoch 16 | Train Acc: 0.3057 | Val Acc: 0.3344 | Train Loss: 2.9575 | Val Loss: 2.8226 | Time: 220.90s
# Current LR: 0.000186
# Epoch 17 | Train Acc: 0.3097 | Val Acc: 0.3504 | Train Loss: 2.9362 | Val Loss: 2.7967 | Time: 221.79s
# Current LR: 0.000184
# Epoch 18 | Train Acc: 0.3169 | Val Acc: 0.3664 | Train Loss: 2.9058 | Val Loss: 2.7432 | Time: 230.20s
# Current LR: 0.000183
# Epoch 19 | Train Acc: 0.3358 | Val Acc: 0.3792 | Train Loss: 2.8738 | Val Loss: 2.7394 | Time: 222.56s
# Current LR: 0.000181
# Epoch 20 | Train Acc: 0.3330 | Val Acc: 0.3901 | Train Loss: 2.8600 | Val Loss: 2.6527 | Time: 221.63s
# Current LR: 0.000179
# Epoch 21 | Train Acc: 0.3412 | Val Acc: 0.3965 | Train Loss: 2.8339 | Val Loss: 2.7276 | Time: 220.29s
# Current LR: 0.000177
# Epoch 22 | Train Acc: 0.3446 | Val Acc: 0.3953 | Train Loss: 2.8162 | Val Loss: 2.6451 | Time: 220.33s
# Current LR: 0.000175
# Epoch 23 | Train Acc: 0.3499 | Val Acc: 0.3786 | Train Loss: 2.8022 | Val Loss: 2.6870 | Time: 220.65s
# Current LR: 0.000173
# Epoch 24 | Train Acc: 0.3596 | Val Acc: 0.4119 | Train Loss: 2.7791 | Val Loss: 2.5969 | Time: 222.80s
# Current LR: 0.000171
# Epoch 25 | Train Acc: 0.3645 | Val Acc: 0.3997 | Train Loss: 2.7582 | Val Loss: 2.5845 | Time: 222.65s
# Current LR: 0.000168
# Epoch 26 | Train Acc: 0.3629 | Val Acc: 0.4241 | Train Loss: 2.7488 | Val Loss: 2.5528 | Time: 223.73s
# Current LR: 0.000166
# Epoch 27 | Train Acc: 0.3768 | Val Acc: 0.4247 | Train Loss: 2.7142 | Val Loss: 2.5276 | Time: 223.51s
# Current LR: 0.000164
# Epoch 28 | Train Acc: 0.3788 | Val Acc: 0.4081 | Train Loss: 2.7012 | Val Loss: 2.5910 | Time: 221.83s
# Current LR: 0.000161
# Epoch 29 | Train Acc: 0.3884 | Val Acc: 0.4279 | Train Loss: 2.6854 | Val Loss: 2.5178 | Time: 219.17s
# Current LR: 0.000159
# Epoch 30 | Train Acc: 0.3892 | Val Acc: 0.4158 | Train Loss: 2.6601 | Val Loss: 2.5560 | Time: 220.73s
# Current LR: 0.000156
# Epoch 31 | Train Acc: 0.3912 | Val Acc: 0.4126 | Train Loss: 2.6544 | Val Loss: 2.5682 | Time: 222.79s
# Current LR: 0.000154
# Epoch 32 | Train Acc: 0.3976 | Val Acc: 0.4478 | Train Loss: 2.6332 | Val Loss: 2.4632 | Time: 227.97s
# Current LR: 0.000151
# Epoch 33 | Train Acc: 0.3972 | Val Acc: 0.4215 | Train Loss: 2.6356 | Val Loss: 2.5274 | Time: 223.80s
# Current LR: 0.000148
# Epoch 34 | Train Acc: 0.4108 | Val Acc: 0.4510 | Train Loss: 2.6054 | Val Loss: 2.4489 | Time: 223.10s
# Current LR: 0.000145
# Epoch 35 | Train Acc: 0.4080 | Val Acc: 0.4452 | Train Loss: 2.5914 | Val Loss: 2.4386 | Time: 223.23s
# Current LR: 0.000143
# Epoch 36 | Train Acc: 0.4143 | Val Acc: 0.4587 | Train Loss: 2.5783 | Val Loss: 2.4275 | Time: 221.60s
# Current LR: 0.000140
# Epoch 37 | Train Acc: 0.4117 | Val Acc: 0.4600 | Train Loss: 2.5706 | Val Loss: 2.4183 | Time: 222.68s
# Current LR: 0.000137
# Epoch 38 | Train Acc: 0.4251 | Val Acc: 0.4651 | Train Loss: 2.5433 | Val Loss: 2.4614 | Time: 222.92s
# Current LR: 0.000134
# Epoch 39 | Train Acc: 0.4255 | Val Acc: 0.4670 | Train Loss: 2.5325 | Val Loss: 2.3902 | Time: 221.54s
# Current LR: 0.000131
# Epoch 40 | Train Acc: 0.4370 | Val Acc: 0.4715 | Train Loss: 2.5174 | Val Loss: 2.3787 | Time: 221.48s
# Current LR: 0.000128
# Epoch 41 | Train Acc: 0.4370 | Val Acc: 0.4753 | Train Loss: 2.5060 | Val Loss: 2.3609 | Time: 220.81s
# Current LR: 0.000125
# Epoch 42 | Train Acc: 0.4390 | Val Acc: 0.4805 | Train Loss: 2.5024 | Val Loss: 2.3743 | Time: 221.40s
# Current LR: 0.000122
# Epoch 43 | Train Acc: 0.4421 | Val Acc: 0.4862 | Train Loss: 2.4879 | Val Loss: 2.3586 | Time: 221.42s
# Current LR: 0.000119
# Epoch 44 | Train Acc: 0.4459 | Val Acc: 0.4606 | Train Loss: 2.4826 | Val Loss: 2.4052 | Time: 223.32s
# Current LR: 0.000116
# Epoch 45 | Train Acc: 0.4513 | Val Acc: 0.5035 | Train Loss: 2.4578 | Val Loss: 2.3152 | Time: 222.56s
# Current LR: 0.000113
# Epoch 46 | Train Acc: 0.4579 | Val Acc: 0.4875 | Train Loss: 2.4477 | Val Loss: 2.3519 | Time: 222.32s
# Current LR: 0.000109
# Epoch 47 | Train Acc: 0.4604 | Val Acc: 0.4888 | Train Loss: 2.4482 | Val Loss: 2.3418 | Time: 224.23s
# Current LR: 0.000106
# Epoch 48 | Train Acc: 0.4611 | Val Acc: 0.5208 | Train Loss: 2.4346 | Val Loss: 2.2556 | Time: 223.38s
# Current LR: 0.000103
# Epoch 49 | Train Acc: 0.4695 | Val Acc: 0.5131 | Train Loss: 2.4119 | Val Loss: 2.2499 | Time: 222.72s
# Current LR: 0.000100
# Epoch 50 | Train Acc: 0.4656 | Val Acc: 0.5016 | Train Loss: 2.4132 | Val Loss: 2.2890 | Time: 225.56s

# %%
import matplotlib.pyplot as plt

def plotAccuracyLoss(trainAccList, valAccList, trainLossList, valLossList):
    Epochs = range(1, len(trainAccList) + 1)

    # Accuracy Plot
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, trainAccList, label='TrainAccuracy', marker='o')
    plt.plot(Epochs, valAccList, label='ValidationAccuracy', marker='o')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, trainLossList, label='TrainLoss', marker='o')
    plt.plot(Epochs, valLossList, label='ValidationLoss', marker='o')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plotAccuracyLoss(trainAccList, valAccList, trainLossList, valLossList)

# %%
def evaluateModel(model, dataLoader, criterion):
    model.eval()
    totalLoss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for images, labels in dataLoader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            totalLoss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    avgLoss = totalLoss / len(dataLoader)
    accuracy = correct / total
    return avgLoss, accuracy

# %%
model.load_state_dict(torch.load("bestModel.pth"))
testLoss, testAcc = evaluateModel(model, testLoader, criterion)
print(f"Test Accuracy: {testAcc*100:.4f} | Test Loss: {testLoss:.4f}")
# Out:
# Test Accuracy: 50.5122 | Test Loss: 2.2738

# %%
allLabels, allPreds = [], []
model.eval()
with torch.no_grad():
    for images, labels in testLoader:
        images = images.to(device)
        outputs = model(images)
        _, preds = outputs.max(1)
        allLabels.extend(labels.cpu().numpy())
        allPreds.extend(preds.cpu().numpy())

cm = confusion_matrix(allLabels, allPreds)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=classNames, yticklabels=classNames, cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

print(classification_report(allLabels, allPreds, target_names=classNames))
# Out:
#                      precision    recall  f1-score   support
#
#      airport_inside       0.47      0.54      0.50        61
#           artstudio       0.00      0.00      0.00        14
#          auditorium       0.42      0.28      0.33        18
#              bakery       0.61      0.41      0.49        41
#                 bar       0.48      0.64      0.55        61
#            bathroom       0.33      0.10      0.15        20
#             bedroom       0.68      0.59      0.63        66
#           bookstore       0.44      0.68      0.54        38
#             bowling       0.65      0.59      0.62        22
#              buffet       0.80      0.36      0.50        11
#              casino       0.61      0.85      0.71        52
#       children_room       0.42      0.45      0.43        11
#       church_inside       0.53      0.44      0.48        18
#           classroom       1.00      0.18      0.31        11
#            cloister       0.92      0.92      0.92        12
#              closet       0.55      0.92      0.69        13
#       clothingstore       0.00      0.00      0.00        10
#        computerroom       0.31      0.36      0.33        11
#        concert_hall       0.45      0.50      0.48        10
#            corridor       0.38      0.71      0.50        35
#                deli       0.29      0.23      0.26        26
#        dentaloffice       0.57      0.31      0.40        13
#         dining_room       0.42      0.29      0.34        28
#            elevator       1.00      0.10      0.18        10
# fastfood_restaurant       0.25      0.18      0.21        11
#             florist       0.70      0.70      0.70        10
#            gameroom       0.30      0.25      0.27        12
#              garage       0.50      0.10      0.17        10
#          greenhouse       0.78      0.70      0.74        10
#        grocerystore       0.57      0.77      0.65        22
#                 gym       0.26      0.48      0.34        23
#           hairsalon       0.23      0.58      0.33        24
#        hospitalroom       0.00      0.00      0.00        10
#          inside_bus       0.80      0.40      0.53        10
#       inside_subway       0.54      0.80      0.65        46
#       jewelleryshop       0.00      0.00      0.00        15
#        kindergarden       0.50      0.58      0.54        12
#             kitchen       0.46      0.69      0.55        74
#       laboratorywet       1.00      0.17      0.29        12
#          laundromat       0.62      0.54      0.58        28
#             library       0.36      0.40      0.38        10
#          livingroom       0.53      0.54      0.53        71
#               lobby       0.50      0.30      0.38        10
#         locker_room       0.37      0.40      0.38        25
#                mall       0.50      0.44      0.47        18
#        meeting_room       0.34      0.48      0.40        23
#        movietheater       0.54      0.72      0.62        18
#              museum       0.00      0.00      0.00        17
#             nursery       0.38      0.43      0.40        14
#              office       0.50      0.09      0.15        11
#      operating_room       0.50      0.23      0.32        13
#              pantry       0.72      0.87      0.79        39
#          poolinside       0.87      0.72      0.79        18
#          prisoncell       1.00      0.30      0.46        10
#          restaurant       0.60      0.46      0.52        52
#  restaurant_kitchen       0.00      0.00      0.00        10
#            shoeshop       0.00      0.00      0.00        11
#          stairscase       0.45      0.33      0.38        15
#         studiomusic       0.67      0.18      0.29        11
#              subway       0.51      0.67      0.58        54
#            toystore       0.56      0.54      0.55        35
#        trainstation       0.71      0.33      0.45        15
#           tv_studio       0.57      0.24      0.33        17
#          videostore       0.43      0.27      0.33        11
#         waitingroom       0.38      0.33      0.36        15
#           warehouse       0.67      0.73      0.70        51
#          winecellar       0.73      0.41      0.52        27
#
#            accuracy                           0.51      1562
#           macro avg       0.50      0.42      0.42      1562
#        weighted avg       0.51      0.51      0.48      1562
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
