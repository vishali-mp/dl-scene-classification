# %% [markdown]
# #We build a custom multi-branch CNN with naive Inception module from scratch and train it on the Indoor Scenes CVPR 2019 dataset.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1: Load image paths and labels from TrainImages.txt and TestImages.txt

# %%
rootDir = '/kaggle/input/indoor-scenes-cvpr-2019/indoorCVPR_09/Images'


with open('/kaggle/input/indoor-scenes-cvpr-2019/TrainImages.txt', 'r') as f:
    trainList = [line.strip() for line in f.readlines()]

with open('/kaggle/input/indoor-scenes-cvpr-2019/TestImages.txt', 'r') as f:
    testList = [line.strip() for line in f.readlines()]

def getLabelFromPath(path):
    return path.split('/')[0]
    
trainFull = [(os.path.join(rootDir, x), getLabelFromPath(x)) for x in trainList]
testFull = [(os.path.join(rootDir, x), getLabelFromPath(x)) for x in testList]

# 80-10-10 split: stratified
trainData, tempData = train_test_split(trainFull, test_size=0.2, stratify=[y for _, y in trainFull], random_state=42)
valData, testData = train_test_split(tempData, test_size=0.5, stratify=[y for _, y in tempData], random_state=42)

# Create label mapping
labelNames = sorted(set([label for _, label in trainFull]))
labelToIndex = {label: idx for idx, label in enumerate(labelNames)}
classNames = labelNames

print(f"Loaded: Train = {len(trainData)}, Val = {len(valData)}, Test = {len(testData)}")
# Out:
# Loaded: Train = 4288, Val = 536, Test = 536

# %% [markdown]
# ## 2: Create custom PyTorch Dataset using parsed image-label pairs

# %%
labelNames = sorted(set([label for _, label in trainFull]))
labelToIndex = {label: idx for idx, label in enumerate(labelNames)}

trainTransform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])


class SceneDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        imgPath, label = self.data[idx]
        image = Image.open(imgPath).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, labelToIndex[label]

# %% [markdown]
# ## 3: Create DataLoaders for training, validation, and testing

# %%
batchSize = 32

trainDataset = SceneDataset(trainData, trainTransform)
valDataset = SceneDataset(valData, transform)
testDataset = SceneDataset(testFull, transform)

trainLoader = DataLoader(trainDataset, batch_size=batchSize, shuffle=True)
valLoader = DataLoader(valDataset, batch_size=batchSize, shuffle=False)
testLoader = DataLoader(testDataset, batch_size=batchSize, shuffle=False)

classNames = labelNames

# %%
def showSamples(dataLoader, classNames, title="Sample Images"):
    images, labels = next(iter(dataLoader))
    plt.figure(figsize=(12, 4))
    for i in range(5):
        img = images[i].permute(1, 2, 0).numpy()  # Convert CHW → HWC
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # Unnormalize
        img = np.clip(img, 0, 1)
        plt.subplot(1, 5, i+1)
        plt.imshow(img)
        plt.title(classNames[labels[i].item()])
        plt.axis('off')
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

showSamples(trainLoader, classNames, title="Train Samples")
showSamples(valLoader, classNames, title="Validation Samples")

# %% [markdown]
# ## 4: Define the custom multi-branch CNN using bottleneck Inception block

# %%
class InceptionBlockOptimized(nn.Module):
    def __init__(self, inChannels, outChannels=128):
        super(InceptionBlockOptimized, self).__init__()
        assert outChannels % 4 == 0
        branch_channels = outChannels // 4

        self.branch1x1 = nn.Sequential(
            nn.Conv2d(inChannels, branch_channels, kernel_size=1),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True)
        )
        self.branch3x3 = nn.Sequential(
            nn.Conv2d(inChannels, branch_channels, kernel_size=1),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(branch_channels, branch_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True)
        )
        self.branch5x5 = nn.Sequential(
            nn.Conv2d(inChannels, branch_channels, kernel_size=1),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(branch_channels, branch_channels, kernel_size=5, padding=2),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True)
        )
        self.branchPool = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            nn.Conv2d(inChannels, branch_channels, kernel_size=1),
            nn.BatchNorm2d(branch_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return torch.cat([
            self.branch1x1(x),
            self.branch3x3(x),
            self.branch5x5(x),
            self.branchPool(x)
        ], dim=1)

class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels, channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(channels)
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(x + self.block(x))

class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction),
            nn.ReLU(inplace=True),
            nn.Linear(channels // reduction, channels),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        w = self.pool(x).view(b, c)
        w = self.fc(w).view(b, c, 1, 1)
        return x * w

class CustomInceptionCNN(nn.Module):
    def __init__(self, numClasses):
        super(CustomInceptionCNN, self).__init__()
        self.stem = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.inception1 = InceptionBlockOptimized(64, 128)
        self.inception2 = InceptionBlockOptimized(128, 256)
        self.inception3 = InceptionBlockOptimized(256, 256)

        self.residual1 = ResidualBlock(256)
        self.residual2 = ResidualBlock(256)
        self.se = SEBlock(256)

        self.globalAvgPool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(256, numClasses)
        )

        self._initWeights()

    def _initWeights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.stem(x)
        x = self.inception1(x)
        x = self.inception2(x)
        x = self.inception3(x)
        x = self.residual1(x)
        x = self.residual2(x)
        x = self.se(x)
        x = self.globalAvgPool(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

# %%
from torchinfo import summary

model = CustomInceptionCNN(numClasses=67)
summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomInceptionCNN                       [1, 67]                   --
# ├─Sequential: 1-1                        [1, 64, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 64, 224, 224]         1,792
# │    └─BatchNorm2d: 2-2                  [1, 64, 224, 224]         128
# │    └─ReLU: 2-3                         [1, 64, 224, 224]         --
# │    └─MaxPool2d: 2-4                    [1, 64, 112, 112]         --
# ├─InceptionBlockOptimized: 1-2           [1, 128, 112, 112]        --
# │    └─Sequential: 2-5                   [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 32, 112, 112]         2,080
# │    │    └─BatchNorm2d: 3-2             [1, 32, 112, 112]         64
# │    │    └─ReLU: 3-3                    [1, 32, 112, 112]         --
# │    └─Sequential: 2-6                   [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-4                  [1, 32, 112, 112]         2,080
# │    │    └─BatchNorm2d: 3-5             [1, 32, 112, 112]         64
# │    │    └─ReLU: 3-6                    [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-7                  [1, 32, 112, 112]         9,248
# │    │    └─BatchNorm2d: 3-8             [1, 32, 112, 112]         64
# │    │    └─ReLU: 3-9                    [1, 32, 112, 112]         --
# │    └─Sequential: 2-7                   [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-10                 [1, 32, 112, 112]         2,080
# │    │    └─BatchNorm2d: 3-11            [1, 32, 112, 112]         64
# │    │    └─ReLU: 3-12                   [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-13                 [1, 32, 112, 112]         25,632
# │    │    └─BatchNorm2d: 3-14            [1, 32, 112, 112]         64
# │    │    └─ReLU: 3-15                   [1, 32, 112, 112]         --
# │    └─Sequential: 2-8                   [1, 32, 112, 112]         --
# │    │    └─MaxPool2d: 3-16              [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-17                 [1, 32, 112, 112]         2,080
# │    │    └─BatchNorm2d: 3-18            [1, 32, 112, 112]         64
# │    │    └─ReLU: 3-19                   [1, 32, 112, 112]         --
# ├─InceptionBlockOptimized: 1-3           [1, 256, 112, 112]        --
# │    └─Sequential: 2-9                   [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-20                 [1, 64, 112, 112]         8,256
# │    │    └─BatchNorm2d: 3-21            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-22                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-10                  [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-23                 [1, 64, 112, 112]         8,256
# │    │    └─BatchNorm2d: 3-24            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-25                   [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-26                 [1, 64, 112, 112]         36,928
# │    │    └─BatchNorm2d: 3-27            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-28                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-11                  [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-29                 [1, 64, 112, 112]         8,256
# │    │    └─BatchNorm2d: 3-30            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-31                   [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-32                 [1, 64, 112, 112]         102,464
# │    │    └─BatchNorm2d: 3-33            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-34                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-12                  [1, 64, 112, 112]         --
# │    │    └─MaxPool2d: 3-35              [1, 128, 112, 112]        --
# │    │    └─Conv2d: 3-36                 [1, 64, 112, 112]         8,256
# │    │    └─BatchNorm2d: 3-37            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-38                   [1, 64, 112, 112]         --
# ├─InceptionBlockOptimized: 1-4           [1, 256, 112, 112]        --
# │    └─Sequential: 2-13                  [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-39                 [1, 64, 112, 112]         16,448
# │    │    └─BatchNorm2d: 3-40            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-41                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-14                  [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-42                 [1, 64, 112, 112]         16,448
# │    │    └─BatchNorm2d: 3-43            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-44                   [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-45                 [1, 64, 112, 112]         36,928
# │    │    └─BatchNorm2d: 3-46            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-47                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-15                  [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-48                 [1, 64, 112, 112]         16,448
# │    │    └─BatchNorm2d: 3-49            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-50                   [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-51                 [1, 64, 112, 112]         102,464
# │    │    └─BatchNorm2d: 3-52            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-53                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-16                  [1, 64, 112, 112]         --
# │    │    └─MaxPool2d: 3-54              [1, 256, 112, 112]        --
# │    │    └─Conv2d: 3-55                 [1, 64, 112, 112]         16,448
# │    │    └─BatchNorm2d: 3-56            [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-57                   [1, 64, 112, 112]         --
# ├─ResidualBlock: 1-5                     [1, 256, 112, 112]        --
# │    └─Sequential: 2-17                  [1, 256, 112, 112]        --
# │    │    └─Conv2d: 3-58                 [1, 256, 112, 112]        590,080
# │    │    └─BatchNorm2d: 3-59            [1, 256, 112, 112]        512
# │    │    └─ReLU: 3-60                   [1, 256, 112, 112]        --
# │    │    └─Conv2d: 3-61                 [1, 256, 112, 112]        590,080
# │    │    └─BatchNorm2d: 3-62            [1, 256, 112, 112]        512
# │    └─ReLU: 2-18                        [1, 256, 112, 112]        --
# ├─ResidualBlock: 1-6                     [1, 256, 112, 112]        --
# │    └─Sequential: 2-19                  [1, 256, 112, 112]        --
# │    │    └─Conv2d: 3-63                 [1, 256, 112, 112]        590,080
# │    │    └─BatchNorm2d: 3-64            [1, 256, 112, 112]        512
# │    │    └─ReLU: 3-65                   [1, 256, 112, 112]        --
# │    │    └─Conv2d: 3-66                 [1, 256, 112, 112]        590,080
# │    │    └─BatchNorm2d: 3-67            [1, 256, 112, 112]        512
# │    └─ReLU: 2-20                        [1, 256, 112, 112]        --
# ├─SEBlock: 1-7                           [1, 256, 112, 112]        --
# │    └─AdaptiveAvgPool2d: 2-21           [1, 256, 1, 1]            --
# │    └─Sequential: 2-22                  [1, 256]                  --
# │    │    └─Linear: 3-68                 [1, 16]                   4,112
# │    │    └─ReLU: 3-69                   [1, 16]                   --
# │    │    └─Linear: 3-70                 [1, 256]                  4,352
# │    │    └─Sigmoid: 3-71                [1, 256]                  --
# ├─AdaptiveAvgPool2d: 1-8                 [1, 256, 1, 1]            --
# ├─Sequential: 1-9                        [1, 67]                   --
# │    └─Dropout: 2-23                     [1, 256]                  --
# │    └─Linear: 2-24                      [1, 67]                   17,219
# ==========================================================================================
# Total params: 2,812,691
# Trainable params: 2,812,691
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 34.98
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 449.58
# Params size (MB): 11.25
# Estimated Total Size (MB): 461.43
# ==========================================================================================

# %% [markdown]
# 5: Setup device, loss function, optimizer, LR scheduler, and early stopping

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CustomInceptionCNN(numClasses=len(classNames)).to(device)

#criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
criterion = nn.CrossEntropyLoss(label_smoothing=0.05)

#optimizer = optim.Adam(model.parameters(), lr=5e-4)
optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.5, verbose=True)
earlyStopPatience = 5
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
def trainModel(model, trainLoader, valLoader, criterion, optimizer, scheduler, epochs=50, earlyStopPatience=5):
    bestValAcc = 0
    patienceCounter = 0

    trainAccList, valAccList, trainLossList, valLossList = [], [], [], []

    for epoch in range(epochs):
        model.train()
        totalTrainLoss, correctTrain, totalTrain = 0, 0, 0

        for images, labels in trainLoader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            totalTrainLoss += loss.item()
            _, preds = outputs.max(1)
            correctTrain += (preds == labels).sum().item()
            totalTrain += labels.size(0)

        trainAcc = correctTrain / totalTrain
        trainLoss = totalTrainLoss / len(trainLoader)

        valLoss, valAcc = evaluateModel(model, valLoader, criterion)

        trainAccList.append(trainAcc)
        valAccList.append(valAcc)
        trainLossList.append(trainLoss)
        valLossList.append(valLoss)

        scheduler.step(valLoss)

        print(f"Epoch {epoch+1:02d} | Train Acc: {trainAcc:.4f} | Val Acc: {valAcc:.4f} | "
              f"Train Loss: {trainLoss:.4f} | Val Loss: {valLoss:.4f}")

        if valAcc > bestValAcc:
            bestValAcc = valAcc
            patienceCounter = 0
            torch.save(model.state_dict(), "bestModel.pth")
        else:
            patienceCounter += 1
            if patienceCounter >= earlyStopPatience:
                print("Early stopping triggered.")
                break

    return trainAccList, valAccList, trainLossList, valLossList

# %%
trainAccList, valAccList, trainLossList, valLossList = trainModel(
    model, trainLoader, valLoader, criterion, optimizer, scheduler,
    epochs=50, earlyStopPatience=5
)
# Out:
# Epoch 01 | Train Acc: 0.0802 | Val Acc: 0.0933 | Train Loss: 3.8803 | Val Loss: 3.6997
# Epoch 02 | Train Acc: 0.0972 | Val Acc: 0.1511 | Train Loss: 3.7626 | Val Loss: 3.5418
# Epoch 03 | Train Acc: 0.1115 | Val Acc: 0.1343 | Train Loss: 3.6691 | Val Loss: 3.6354
# Epoch 04 | Train Acc: 0.1243 | Val Acc: 0.1586 | Train Loss: 3.5807 | Val Loss: 3.4413
# Epoch 05 | Train Acc: 0.1434 | Val Acc: 0.1586 | Train Loss: 3.5111 | Val Loss: 3.3978
# Epoch 06 | Train Acc: 0.1546 | Val Acc: 0.1716 | Train Loss: 3.4680 | Val Loss: 3.3703
# Epoch 07 | Train Acc: 0.1695 | Val Acc: 0.2052 | Train Loss: 3.3897 | Val Loss: 3.2632
# Epoch 08 | Train Acc: 0.1698 | Val Acc: 0.2071 | Train Loss: 3.3580 | Val Loss: 3.2117
# Epoch 09 | Train Acc: 0.1789 | Val Acc: 0.1959 | Train Loss: 3.3072 | Val Loss: 3.2632
# Epoch 10 | Train Acc: 0.1873 | Val Acc: 0.2537 | Train Loss: 3.2698 | Val Loss: 3.1221
# Epoch 11 | Train Acc: 0.2050 | Val Acc: 0.2351 | Train Loss: 3.2193 | Val Loss: 3.1275
# Epoch 12 | Train Acc: 0.2066 | Val Acc: 0.2687 | Train Loss: 3.1861 | Val Loss: 3.0735
# Epoch 13 | Train Acc: 0.2250 | Val Acc: 0.2612 | Train Loss: 3.1446 | Val Loss: 3.0743
# Epoch 14 | Train Acc: 0.2327 | Val Acc: 0.2351 | Train Loss: 3.1057 | Val Loss: 3.1495
# Epoch 15 | Train Acc: 0.2274 | Val Acc: 0.2817 | Train Loss: 3.0793 | Val Loss: 2.9778
# Epoch 16 | Train Acc: 0.2451 | Val Acc: 0.2892 | Train Loss: 3.0310 | Val Loss: 2.9937
# Epoch 17 | Train Acc: 0.2453 | Val Acc: 0.2500 | Train Loss: 3.0131 | Val Loss: 3.1173
# Epoch 18 | Train Acc: 0.2614 | Val Acc: 0.2556 | Train Loss: 2.9716 | Val Loss: 3.0829
# Epoch 19 | Train Acc: 0.2603 | Val Acc: 0.2780 | Train Loss: 2.9564 | Val Loss: 2.9326
# Epoch 20 | Train Acc: 0.2740 | Val Acc: 0.2985 | Train Loss: 2.9342 | Val Loss: 2.9207
# Epoch 21 | Train Acc: 0.2759 | Val Acc: 0.2985 | Train Loss: 2.8955 | Val Loss: 2.8744
# Epoch 22 | Train Acc: 0.2850 | Val Acc: 0.2668 | Train Loss: 2.8700 | Val Loss: 3.0909
# Epoch 23 | Train Acc: 0.2875 | Val Acc: 0.2649 | Train Loss: 2.8523 | Val Loss: 2.9602
# Epoch 24 | Train Acc: 0.2931 | Val Acc: 0.3172 | Train Loss: 2.8222 | Val Loss: 2.8640
# Epoch 25 | Train Acc: 0.3025 | Val Acc: 0.3060 | Train Loss: 2.7920 | Val Loss: 2.8294
# Epoch 26 | Train Acc: 0.2997 | Val Acc: 0.2966 | Train Loss: 2.7869 | Val Loss: 2.8858
# Epoch 27 | Train Acc: 0.3179 | Val Acc: 0.2966 | Train Loss: 2.7581 | Val Loss: 2.8253
# Epoch 28 | Train Acc: 0.3216 | Val Acc: 0.2705 | Train Loss: 2.7075 | Val Loss: 2.9329
# Epoch 29 | Train Acc: 0.3200 | Val Acc: 0.3340 | Train Loss: 2.7104 | Val Loss: 2.7746
# Epoch 30 | Train Acc: 0.3361 | Val Acc: 0.3041 | Train Loss: 2.6586 | Val Loss: 2.8496
# Epoch 31 | Train Acc: 0.3351 | Val Acc: 0.3246 | Train Loss: 2.6514 | Val Loss: 2.7494
# Epoch 32 | Train Acc: 0.3412 | Val Acc: 0.3172 | Train Loss: 2.6429 | Val Loss: 2.7893
# Epoch 33 | Train Acc: 0.3433 | Val Acc: 0.3582 | Train Loss: 2.6202 | Val Loss: 2.7390
# Epoch 34 | Train Acc: 0.3510 | Val Acc: 0.3172 | Train Loss: 2.5948 | Val Loss: 2.7700
# Epoch 35 | Train Acc: 0.3463 | Val Acc: 0.3340 | Train Loss: 2.5955 | Val Loss: 2.7303
# Epoch 36 | Train Acc: 0.3701 | Val Acc: 0.3638 | Train Loss: 2.5413 | Val Loss: 2.6405
# Epoch 37 | Train Acc: 0.3769 | Val Acc: 0.3302 | Train Loss: 2.5187 | Val Loss: 2.8127
# Epoch 38 | Train Acc: 0.3848 | Val Acc: 0.3302 | Train Loss: 2.4859 | Val Loss: 2.7792
# Epoch 39 | Train Acc: 0.3818 | Val Acc: 0.3228 | Train Loss: 2.4827 | Val Loss: 2.7674
# Epoch 40 | Train Acc: 0.4007 | Val Acc: 0.3134 | Train Loss: 2.4537 | Val Loss: 2.9473
# Epoch 41 | Train Acc: 0.4272 | Val Acc: 0.3937 | Train Loss: 2.3570 | Val Loss: 2.5526
# Epoch 42 | Train Acc: 0.4440 | Val Acc: 0.3769 | Train Loss: 2.2863 | Val Loss: 2.6282
# Epoch 43 | Train Acc: 0.4410 | Val Acc: 0.3974 | Train Loss: 2.3080 | Val Loss: 2.5554
# Epoch 44 | Train Acc: 0.4422 | Val Acc: 0.4235 | Train Loss: 2.2925 | Val Loss: 2.5310
# Epoch 45 | Train Acc: 0.4394 | Val Acc: 0.4030 | Train Loss: 2.2730 | Val Loss: 2.5642
# Epoch 46 | Train Acc: 0.4508 | Val Acc: 0.4142 | Train Loss: 2.2484 | Val Loss: 2.5570
# Epoch 47 | Train Acc: 0.4401 | Val Acc: 0.3937 | Train Loss: 2.2638 | Val Loss: 2.5663
# Epoch 48 | Train Acc: 0.4650 | Val Acc: 0.4104 | Train Loss: 2.2302 | Val Loss: 2.5206
# Epoch 49 | Train Acc: 0.4555 | Val Acc: 0.4011 | Train Loss: 2.2204 | Val Loss: 2.5186
# Early stopping triggered.

# %%
def evaluateModel(model, dataLoader, criterion):
    model.eval()
    totalLoss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for images, labels in dataLoader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            totalLoss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    avgLoss = totalLoss / len(dataLoader)
    accuracy = correct / total
    return avgLoss, accuracy

# %%
model.load_state_dict(torch.load("bestModel.pth"))
testLoss, testAcc = evaluateModel(model, testLoader, criterion)
print(f"Test Accuracy: {testAcc:.4f} | Test Loss: {testLoss:.4f}")
# Out:
# Test Accuracy: 0.3828 | Test Loss: 2.5808

# %%
allLabels, allPreds = [], []
model.eval()
with torch.no_grad():
    for images, labels in testLoader:
        images = images.to(device)
        outputs = model(images)
        _, preds = outputs.max(1)
        allLabels.extend(labels.cpu().numpy())
        allPreds.extend(preds.cpu().numpy())

cm = confusion_matrix(allLabels, allPreds)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=classNames, yticklabels=classNames, cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

print(classification_report(allLabels, allPreds, target_names=classNames))
# Out:
#                      precision    recall  f1-score   support
#
#      airport_inside       0.39      0.35      0.37        20
#           artstudio       0.11      0.05      0.07        20
#          auditorium       0.57      0.44      0.50        18
#              bakery       0.60      0.16      0.25        19
#                 bar       0.33      0.39      0.36        18
#            bathroom       0.13      0.22      0.16        18
#             bedroom       0.27      0.19      0.22        21
#           bookstore       0.38      0.30      0.33        20
#             bowling       0.44      0.55      0.49        20
#              buffet       0.60      0.60      0.60        20
#              casino       0.61      0.74      0.67        19
#       children_room       0.20      0.17      0.18        18
#       church_inside       0.42      0.53      0.47        19
#           classroom       0.38      0.56      0.45        18
#            cloister       0.71      0.75      0.73        20
#              closet       0.43      0.50      0.46        18
#       clothingstore       0.56      0.28      0.37        18
#        computerroom       0.31      0.50      0.38        18
#        concert_hall       0.54      0.75      0.63        20
#            corridor       0.25      0.33      0.29        21
#                deli       0.33      0.11      0.16        19
#        dentaloffice       0.36      0.19      0.25        21
#         dining_room       0.53      0.44      0.48        18
#            elevator       0.36      0.38      0.37        21
# fastfood_restaurant       0.21      0.47      0.29        17
#             florist       0.76      0.84      0.80        19
#            gameroom       0.38      0.30      0.33        20
#              garage       0.37      0.39      0.38        18
#          greenhouse       0.86      0.95      0.90        20
#        grocerystore       0.41      0.81      0.55        21
#                 gym       0.35      0.50      0.41        18
#           hairsalon       0.50      0.38      0.43        21
#        hospitalroom       0.18      0.35      0.24        20
#          inside_bus       0.50      0.65      0.57        23
#       inside_subway       0.45      0.43      0.44        21
#       jewelleryshop       0.14      0.14      0.14        22
#        kindergarden       0.41      0.45      0.43        20
#             kitchen       0.12      0.05      0.07        21
#       laboratorywet       0.41      0.55      0.47        22
#          laundromat       0.32      0.36      0.34        22
#             library       0.30      0.45      0.36        20
#          livingroom       0.00      0.00      0.00        20
#               lobby       0.25      0.10      0.14        20
#         locker_room       0.24      0.38      0.29        21
#                mall       0.57      0.20      0.30        20
#        meeting_room       0.45      0.23      0.30        22
#        movietheater       0.57      0.65      0.60        20
#              museum       0.44      0.17      0.25        23
#             nursery       0.39      0.75      0.52        20
#              office       0.00      0.00      0.00        21
#      operating_room       0.56      0.47      0.51        19
#              pantry       0.48      0.50      0.49        20
#          poolinside       0.54      0.65      0.59        20
#          prisoncell       0.14      0.20      0.16        20
#          restaurant       0.33      0.05      0.09        20
#  restaurant_kitchen       0.60      0.13      0.21        23
#            shoeshop       0.50      0.16      0.24        19
#          stairscase       0.29      0.50      0.37        20
#         studiomusic       0.88      0.37      0.52        19
#              subway       0.28      0.57      0.37        21
#            toystore       0.80      0.18      0.30        22
#        trainstation       0.42      0.40      0.41        20
#           tv_studio       0.15      0.11      0.13        18
#          videostore       0.37      0.45      0.41        22
#         waitingroom       0.11      0.10      0.10        21
#           warehouse       0.21      0.29      0.24        21
#          winecellar       0.54      0.62      0.58        21
#
#            accuracy                           0.38      1340
#           macro avg       0.40      0.38      0.37      1340
#        weighted avg       0.40      0.38      0.36      1340

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Compute Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
fig, ax = plt.subplots(figsize=(18, 18))  # Increase figure size

# Plot
sns.heatmap(cm, annot=False, fmt='d', cmap='Blues', ax=ax)

# Improve label visibility
ax.set_title('Confusion Matrix', fontsize=16)
ax.set_xlabel('Predicted Label', fontsize=14)
ax.set_ylabel('True Label', fontsize=14)

# Rotate labels and reduce font size
ax.set_xticklabels(class_names, rotation=90, fontsize=6)
ax.set_yticklabels(class_names, rotation=0, fontsize=6)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/1628125867.py in <cell line: 0>()
#       5
#       6 # Compute Confusion Matrix
# ----> 7 cm = confusion_matrix(true_labels, predicted_labels)
#       8 fig, ax = plt.subplots(figsize=(18, 18))  # Increase figure size
#       9
#
# NameError: name 'true_labels' is not defined
